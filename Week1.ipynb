# %% [markdown]
# <a href="https://colab.research.google.com/github/SabilarRosyad/PCVK_GENAP_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pyplot as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tingg x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# - Karena pada praktikum kali ini, saya rasa lebih enak dan simple menggunakan google colab untuk mengerjakannya.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - Numpy : digunakan untuk memudahkan melakukan perhitungan seperti matriks, aljabar dan lain-lain
# - Pandas : library untuk analisis data dan manipulasi data
# - CV2 : library untuk melakukan tugas visi komputer
# - Skimage : library untuk mensupport proses image  di python
# - Matploitlib : library untuk menghasilkan angka dan menyediakan perangkat antarmuka pengguna grafis
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# - untuk mengubah ambar menjadi setengah ukuran
#
# 4. Perhatikan potongan kode progam berikut :
#
# Apakah kegunaan kode [255,255,255] ? Jelaskan!
# - untuk memperpanjang garis yang ada ditengah
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# - Pixel dan resolusi sangat berkaitan, jadi jika resolusi gambar nya tinggi maka akan ada semakin banyak pixel dan juga sebaliknya jika resolusi gambar rendah maka pixel nya hanya sedikit

# %% [markdown]
# ##Tugas

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis diagonal ditengah image
image_3 = cv.line(image_3, (0,0), (lebar,tinggi), (255,255,255), 1)

#membuat garis diagonal ditengah image
image_3 = cv.line(image_3, (0,tinggi), (lebar,0), (255,255,255), 1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#membuat garis di tengah
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (25,100):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#membuat kotak di sembarang tempat
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (25,100):
  for x in range (25,100):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_ktp = io.imread("KTP.jpeg")
image_ktp = cv.resize(image_ktp, (0,0), fx=0.5, fy=0.5)
image_ktp2 = cv.cvtColor(image_ktp, cv.COLOR_BGR2RGB)
cv2_imshow(image_ktp2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x244>

# %%
image_ktp = io.imread("KTP.jpeg")
image_ktp = cv.resize(image_ktp, (0,0), fx=0.5, fy=0.5)
image_ktp2 = cv.cvtColor(image_ktp, cv.COLOR_BGR2RGB)

for y in range(95,200):
  for x in range(94,102):
    image_ktp2[x,y] =[0,0,255]

for y in range(95,200):
  for x in range(130,138):
    image_ktp2[x,y] =[0,255,0]

cv2_imshow(image_ktp2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x244>
